# %% [markdown]
# <a href="https://colab.research.google.com/github/Bunny825/calories-burnt-in-exercise/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics

# %%
exercise=pd.read_csv("/content/exercise.csv")
calories=pd.read_csv("/content/calories.csv")
calories_data=pd.concat([exercise,calories["Calories"]],axis=1)

# %%
calories_data.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
calories_data.shape
# Out:
# (15000, 9)

# %%
calories_data.isnull().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %%
calories_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
calories_data.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %%
#Visualisations

sns.set()
sns.countplot(data=calories_data,x="Gender")
plt.show()

# %%
sns.displot(calories_data["Age"],kde=True)
plt.show()

# %%
sns.displot(calories_data["Height"],kde=True)
plt.show()

# %%
sns.displot(calories_data["Weight"],kde=True)
plt.show()

# %%
sns.displot(calories_data["Duration"],kde=True)
plt.show()

# %%
sns.displot(calories_data["Heart_Rate"],kde=True)
plt.show()

# %%
sns.displot(calories_data["Body_Temp"],kde=True)
plt.show()

# %%
sns.displot(calories_data["Calories"],kde=True)
plt.show()

# %%
calories_data.replace({"Gender":{"male":0,"female":1}},inplace=True)

# %%
calories_data.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363       0   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698       1   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863       0   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408       1   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927       1   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
correlation=calories_data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation,cbar=True,square=True,fmt=".1f",annot=True,annot_kws={"size":8},cmap="Blues")
plt.show()

# %%
x=calories_data.drop(columns="Calories",axis=1)
y=calories_data["Calories"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2,test_size=0.2)
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (15000, 8) (12000, 8) (3000, 8)

# %%
model=XGBRegressor()
model.fit(x_train,y_train)

train_pred=model.predict(x_train)
test_pred=model.predict(x_test)

train_score=metrics.mean_absolute_error(y_train,train_pred)

test_score=metrics.mean_absolute_error(y_test,test_pred)

print(train_score,test_score)
# Out:
# 0.9740070718588928 1.57148710261782
